# %% [markdown]
# # 📊 Data Analysis Project: Superstore Sales Dataset
#
# ## 📖 Introduction
#
# In this project, we analyze the **Superstore Sales Dataset** to uncover valuable business insights and support data-driven decision-making. Retail businesses generate large amounts of sales data every day, making data analysis essential for understanding customer behavior, product performance, and sales trends.
#
# This project focuses on cleaning, exploring, and visualizing the dataset to answer important business questions. Through Exploratory Data Analysis (EDA), we identify sales patterns, top-performing products, customer segments, and regional performance. The results help transform raw data into meaningful insights that can support better business decisions.
#
# ---
#
# ## 🎯 Objectives
#
# - Perform data cleaning and preprocessing.
# - Explore the dataset using descriptive statistics.
# - Analyze sales performance across different categories, regions, customers, and products.
# - Visualize key trends and patterns using charts.
# - Extract meaningful business insights.
# - Present the results in a clear and professional manner.
#
# ---
#
# ## 🛠️ Tools & Technologies
#
# - Python 🐍
# - Pandas
# - Matplotlib
# - SQL
# - Tableau
# - Jupyter Notebook
#
# ---
#
# ## 📂 Dataset
#
# The dataset used in this project was sourced from **Kaggle** and contains **9,800 rows** and **18 columns**.
#
# It includes valuable information about:
#
# - Customer Information
# - Product Information
# - Sales Transactions
# - Order & Shipping Details
# - Categories & Sub-Categories
# - Regional Performance
#
# This dataset provides a comprehensive view of retail sales operations, making it suitable for business analysis and data visualization.
#
# ---
#
# ## 📌 Project Workflow
#
# The project follows these main steps:
#
# 1. Import Libraries
# 2. Load the Dataset
# 3. Data Exploration
# 4. Data Cleaning & Preprocessing
# 5. Exploratory Data Analysis (EDA)
# 6. Data Visualization
# 7. Business Insights
# 8. Dashboard Creation (Tableau)
# 9. Final Presentation
#
# ---
#
# ## 💡 Project Outcome
#
# This project demonstrates how data analysis can transform raw sales data into meaningful insights that support business decision-making.
#
# By analyzing sales performance, customer behavior, product categories, and regional trends, businesses can identify growth opportunities, optimize their sales strategies, and make more informed decisions based on data.

# %%
# ==========================================
# Import Required Libraries
# ==========================================
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ==========================================
# Load the Dataset
# ==========================================

df = pd.read_csv("Superstore Sales Dataset.csv")

# %%
# ==========================================
# Display the First 5 Rows
# ==========================================

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# ==========================================
# Display Dataset Information
# ==========================================

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
# ==========================================
# Display Dataset Shape
# ==========================================

df.shape
# Out:
# (9800, 18)

# %%
# ==========================================
# Display Column Names
# ==========================================

df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
# ==========================================
# Check Missing Values
# ==========================================

df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
# ==========================================
# Check Duplicate Records
# ==========================================

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Basic Statistics

# %%
# ==========================================
# Display Statistical Summary
# ==========================================

df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
# ==========================================
# Calculate Total Sales
# ==========================================

df["Sales"].sum()
# Out:
# np.float64(2261536.7827)

# %%
# ==========================================
# Calculate Total Orders
# ==========================================

df["Order ID"].nunique()
# Out:
# 4922

# %%
# ==========================================
# Calculate Total Customers
# ==========================================

df["Customer ID"].nunique()
# Out:
# 793

# %%
# ==========================================
# Sales by Category
# ==========================================

df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
# ==========================================
# Sales by Region
# ==========================================

df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
# ==========================================
# Top 10 Customers by Sales
# ==========================================

df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
# ==========================================
# Top 10 Products by Sales
# ==========================================

df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
# ==========================================
# Sales by Category Visualization
# ==========================================

category_sales = df.groupby("Category")["Sales"].sum()

category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.xticks(rotation=0)

plt.show()

# %%
# ==========================================
# Sales by Region Visualization
# ==========================================

region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=0)

plt.show()

# %%
# ==========================================
# Top 10 Customers Visualization
# ==========================================

top_customers = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)

top_customers.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 Customers")
plt.xlabel("Customer")
plt.ylabel("Sales")
plt.xticks(rotation=45)

plt.show()

# %%
# ==========================================
# Top 10 Products Visualization
# ==========================================

top_products = df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)

top_products.plot(kind="bar", figsize=(10,5))

plt.title("Top 10 Products")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.xticks(rotation=90)

plt.show()

# %%
# ==========================================
# Monthly Sales Trend
# ==========================================

# Convert 'Order Date' to datetime format
df["Order Date"] = pd.to_datetime(df["Order Date"], format="mixed", errors="coerce")

# Remove invalid dates
df = df.dropna(subset=["Order Date"])

# Create a new column for Year-Month
df["Month"] = df["Order Date"].dt.to_period("M")

# Calculate total sales for each month
monthly_sales = df.groupby("Month")["Sales"].sum()

# Plot the monthly sales trend
monthly_sales.plot(kind="line", figsize=(10,5))

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid(True)

plt.show()

# %% [markdown]
# # Conclusion
#
# This analysis revealed that Technology is the highest-performing category, the West region generates the largest share of sales, and sales generally show positive growth over time. These insights can help decision-makers improve marketing strategies, optimize inventory, and focus on high-value customers and products.
